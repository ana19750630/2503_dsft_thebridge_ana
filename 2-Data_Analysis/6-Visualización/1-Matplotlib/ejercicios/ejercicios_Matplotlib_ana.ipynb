# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar valores para el eje X entre 0 y 5, con 100 puntos (alta precisión)
x = np.linspace(0, 5, 100)

# Calcular las rectas
y1 = 3 * x  # recta con pendiente positiva de 3 pasando por (0,0)
y2 = -3 * x - 5  # recta con pendiente negativa de 3 pasando por (0,-5)

# Crear una figura
plt.figure(figsize=(10, 5))

# Graficar la primera recta (a la izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(x, y1, label='y = 3x', color='blue')
plt.title('Recta con pendiente positiva')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

# Graficar la segunda recta (a la derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(x, y2, label='y = -3x - 5', color='red')
plt.title('Recta con pendiente negativa')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

# Mostrar los gráficos
plt.tight_layout()  # Ajusta el espaciado para evitar solapamientos
plt.show()

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar valores para el eje X entre 0 y 5, con 100 puntos (alta precisión)
x = np.linspace(0, 5, 100)

# Calcular las rectas
y1 = 3 * x  # recta con pendiente positiva de 3 pasando por (0,0)
y2 = -3 * x - 5  # recta con pendiente negativa de 3 pasando por (0,-5)

# Crear una figura
plt.figure(figsize=(10, 5))

# Graficar la primera recta (a la izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(x, y1, label='y = 3x', color='blue')
plt.title('Recta con pendiente positiva')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 5)  # Fijar el eje X entre 0 y 5
plt.ylim(-15, 15)  # Fijar el eje Y entre -15 y 15
plt.grid(True)
plt.legend()

# Graficar la segunda recta (a la derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(x, y2, label='y = -3x - 5', color='red')
plt.title('Recta con pendiente negativa')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 5)  # Fijar el eje X entre 0 y 5
plt.ylim(-15, 15)  # Fijar el eje Y entre -15 y 15
plt.grid(True)
plt.legend()

# Mostrar los gráficos
plt.tight_layout()  # Ajusta el espaciado para evitar solapamientos
plt.show()

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar valores para el eje X entre 0 y 5, con 100 puntos (alta precisión)
x = np.linspace(0, 5, 100)

# Calcular las rectas
y1 = 3 * x  # recta con pendiente positiva de 3 pasando por (0,0)
y2 = -3 * x - 5  # recta con pendiente negativa de 3 pasando por (0,-5)

# Crear una figura
plt.figure(figsize=(10, 5))

# Graficar la primera recta (a la izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(x, y1, label='y = 3x', color='blue')
plt.title('Recta sube')  # Título de la gráfica
plt.xlabel('eje X')  # Etiqueta del eje X
plt.ylabel('eje Y')  # Etiqueta del eje Y
plt.xlim(0, 5)  # Fijar el eje X entre 0 y 5
plt.ylim(-15, 15)  # Fijar el eje Y entre -15 y 15
plt.xticks([0, 5])  # Mostrar solo dos etiquetas del eje X
plt.yticks([-15, 0, 15])  # Mostrar solo una etiqueta del eje Y
plt.grid(True)
plt.legend()

# Graficar la segunda recta (a la derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(x, y2, label='y = -3x - 5', color='red')
plt.title('Recta baja')  # Título de la gráfica
plt.xlabel('eje X')  # Etiqueta del eje X
plt.ylabel('eje Y')  # Etiqueta del eje Y
plt.xlim(0, 5)  # Fijar el eje X entre 0 y 5
plt.ylim(-15, 15)  # Fijar el eje Y entre -15 y 15
plt.xticks([0, 5])  # Mostrar solo dos etiquetas del eje X
plt.yticks([-15, 0, 15])  # Mostrar solo una etiqueta del eje Y
plt.grid(True)
plt.legend()

# Mostrar los gráficos
plt.tight_layout()  # Ajusta el espaciado para evitar solapamientos
plt.show()

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar valores para el eje X entre 0 y 5, con 100 puntos (alta precisión)
x = np.linspace(0, 5, 100)

# Calcular las rectas
y1 = 3 * x  # recta con pendiente positiva de 3 pasando por (0,0)
y2 = -3 * x - 5  # recta con pendiente negativa de 3 pasando por (0,-5)

# Crear una figura
fig = plt.figure(figsize=(10, 5))

# Crear los ejes para la primera gráfica (a la izquierda)
ax1 = fig.add_subplot(121)  # 1 fila, 2 columnas, primer gráfico
ax1.plot(x, y1, label='y = 3x', color='blue')
ax1.set_title('Recta con pendiente positiva')
ax1.set_xlabel('eje X')
ax1.set_ylabel('eje Y')
ax1.set_xlim(0, 5)  # Fijar el eje X entre 0 y 5
ax1.set_ylim(-15, 15)  # Fijar el eje Y entre -15 y 15
ax1.grid(True)
ax1.legend()

# Crear los ejes para la segunda gráfica (a la derecha)
ax2 = fig.add_subplot(122)  # 1 fila, 2 columnas, segundo gráfico
ax2.plot(x, y2, label='y = -3x - 5', color='red')
ax2.set_title('Recta con pendiente negativa')
ax2.set_xlabel('eje X')
ax2.set_ylabel('eje Y')
ax2.set_xlim(0, 5)  # Fijar el eje X entre 0 y 5
ax2.set_ylim(-15, 15)  # Fijar el eje Y entre -15 y 15
ax2.grid(True)
ax2.legend()

# Ajustar el layout de la figura para evitar solapamientos
plt.tight_layout()

# Mostrar la figura
plt.show()

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
import matplotlib.pyplot as plt

# Coordenadas X y Y
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

# Crear un gráfico de barras
plt.bar(x, y, color='blue')

# Añadir título y etiquetas
plt.title('Gráfico de barras')
plt.xlabel('X')
plt.ylabel('Y')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
import matplotlib.pyplot as plt

# Nombres de los amigos
amigos = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']

# Alturas de los amigos en centímetros
alturas = [160, 180, 175, 190, 170]

# Crear un gráfico de barras con las barras en color verde
plt.bar(amigos, alturas, color='green')

# Añadir título y etiquetas
plt.title('Altura de un grupo de amigos')
plt.xlabel('Amigos')
plt.ylabel('Altura (cm)')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
import matplotlib.pyplot as plt

# Nombres de los amigos
amigos = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']

# Alturas de los amigos en centímetros
alturas = [160, 180, 175, 190, 170]

# Crear un gráfico de barras con las barras en color verde y el tamaño de la figura cambiado
plt.figure(figsize=(3, 5))  # Cambiar el tamaño de la figura
plt.bar(amigos, alturas, color='green')

# Añadir título y etiquetas
plt.title('Altura de un grupo de amigos')
plt.xlabel('Amigos')
plt.ylabel('Altura (cm)')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
import matplotlib.pyplot as plt

# Nombres de los amigos
amigos = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']

# Alturas de los amigos en centímetros
alturas = [160, 180, 175, 190, 170]

# Crear un gráfico de barras con las barras en color verde y el tamaño de la figura cambiado
plt.figure(figsize=(3, 5))  # Cambiar el tamaño de la figura
plt.bar(amigos, alturas, color='green')

# Añadir título y etiquetas
plt.title('Altura de un grupo de amigos')
plt.xlabel('Amigos')
plt.ylabel('Altura (cm)')

# Eliminar la escala del eje Y
plt.yticks([])  # Elimina las marcas y etiquetas del eje Y

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
import matplotlib.pyplot as plt

# Nombres de los amigos
amigos = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']

# Alturas de los amigos en centímetros
alturas = [160, 180, 175, 190, 170]

# Crear un gráfico de barras horizontal con las barras en color verde y el tamaño de la figura cambiado
plt.figure(figsize=(5, 3))  # Cambiar el tamaño de la figura (más ancho)
plt.barh(amigos, alturas, color='green')  # Usar barh para barras horizontales

# Añadir título y etiquetas
plt.title('Altura de un grupo de amigos')
plt.xlabel('Altura (cm)')
plt.ylabel('Amigos')

# Eliminar la escala del eje Y
plt.yticks([])  # Elimina las marcas y etiquetas del eje Y

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
import matplotlib.pyplot as plt

# Nombres de los amigos
amigos = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']

# Alturas de los amigos en centímetros
alturas = [160, 180, 175, 190, 170]

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(5, 3))  # Crear la figura y los ejes

# Crear un gráfico de barras horizontal con las barras en color verde
ax.barh(amigos, alturas, color='green')

# Añadir título y etiquetas
ax.set_title('Altura de un grupo de amigos')
ax.set_xlabel('Altura (cm)')
ax.set_ylabel('Amigos')

# Eliminar la escala del eje Y
ax.set_yticks([])  # Elimina las marcas y etiquetas del eje Y

# Invertir los ejes
ax.invert_yaxis()  # Invierte el eje Y

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
import matplotlib.pyplot as plt

# Cambiar el estilo a 'dark_background'
plt.style.use('dark_background')

# Nombres de los amigos
amigos = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']

# Alturas de los amigos en centímetros
alturas = [160, 180, 175, 190, 170]

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(5, 3))  # Crear la figura y los ejes

# Crear un gráfico de barras horizontal con las barras en color verde
ax.barh(amigos, alturas, color='green')

# Añadir título y etiquetas
ax.set_title('Altura de un grupo de amigos')
ax.set_xlabel('Altura (cm)')
ax.set_ylabel('Amigos')

# Eliminar la escala del eje Y
ax.set_yticks([])  # Elimina las marcas y etiquetas del eje Y

# Invertir los ejes
ax.invert_yaxis()  # Invierte el eje Y

# Mostrar el gráfico
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
import pandas as pd
data = {"Year": [2015, 2016, 2017,2018, 2019],
        "Sold_items_A" :[1000, 3500, 4000, 5500, 7000]
        }
dframe = pd.DataFrame(data)
dframe
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# Verificar los estilos disponibles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('default')

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Crear los datos en un diccionario
data = {
    "Year": [2015, 2016, 2017, 2018, 2019],
    "Sold_items_A": [1000, 3500, 4000, 5500, 7000]
}

# Crear el DataFrame
dframe = pd.DataFrame(data)

# Crear el gráfico de línea
plt.plot(dframe['Year'], dframe['Sold_items_A'], color='blue', marker='o', label='Ventas')

# Añadir título y etiquetas a los ejes
plt.title('Ventas de Productos A a lo largo de los años')
plt.xlabel('Año')
plt.ylabel('Ventas de Productos A')

# Mostrar leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear los datos en un diccionario
data = {
    "Year": [2015, 2016, 2017, 2018, 2019],
    "Sold_items_A": [1000, 3500, 4000, 5500, 7000]
}

# Crear el DataFrame
dframe = pd.DataFrame(data)

# Cambiar el estilo del gráfico a 'seaborn-white' (## ESTE ME DA ERROR)
##plt.style.use('seaborn-white')

# Crear el gráfico de línea con la línea verde y rayada
plt.plot(dframe['Year'], dframe['Sold_items_A'], color='green', linestyle='--', marker='o', label='Ventas')

# Añadir título y etiquetas a los ejes
plt.title('Ventas de Productos A a lo largo de los años')
plt.xlabel('Año')
plt.ylabel('Ventas de Productos A')

# Mostrar leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Añadir la columna de ventas del Departamento B
dframe['Sold_items_B'] = [2000, 3100, 5000, 4000, 6000]

print(dframe)
# Out:
#    Year  Sold_items_A  Sold_items_B
# 0  2015          1000          2000
# 1  2016          3500          3100
# 2  2017          4000          5000
# 3  2018          5500          4000
# 4  2019          7000          6000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Añadir la columna de ventas del Departamento B
dframe['Sold_items_B'] = [2000, 3100, 5000, 4000, 6000]

# Crear el gráfico
plt.figure(figsize=(8, 5))

# %%
# Graficar las ventas del Departamento A (línea sólida)
plt.plot(dframe['Year'], dframe['Sold_items_A'], label='Departamento A', color='blue', linestyle='-', marker='o')

# Graficar las ventas del Departamento B (línea punteada)
plt.plot(dframe['Year'], dframe['Sold_items_B'], label='Departamento B', color='red', linestyle='--', marker='x')

# Añadir título y etiquetas
plt.title('Ventas por Departamento (2015-2019)')
plt.xlabel('Año')
plt.ylabel('Unidades Vendidas')

# Mostrar la leyenda en la esquina inferior derecha
plt.legend(loc='lower right')

# Mostrar el gráfico
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
import pandas as pd


# Crear el DataFrame
##dframe = pd.DataFrame(data)

# Crear el gráfico de dispersión (scatter) para el Departamento A
dframe.plot(x='Year', y='Sold_items_A', kind='scatter', color='blue', title='Ventas del Departamento A')

# Mostrar el gráfico
plt.xlabel('Año')
plt.ylabel('Unidades Vendidas')
plt.grid(True)
plt.show()

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
import pandas as pd


# Crear el DataFrame
##dframe = pd.DataFrame(data)

# Crear el gráfico de dispersión (scatter) para el Departamento A
dframe.plot(x='Year', y='Sold_items_A', kind='pie', color='blue', title='Ventas del Departamento A')

# Mostrar el gráfico
plt.xlabel('Año')
plt.ylabel('Unidades Vendidas')
plt.grid(True)
plt.show()

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Crear un gráfico de pastel (pie chart) para las ventas por año
dframe.plot(kind='pie', 
            y='Sold_items_A', 
            labels=dframe['Year'], 
            autopct='%1.1f%%', 
            figsize=(8, 8), 
            legend=False)  # Eliminar la leyenda

# Título del gráfico
plt.title('Distribución de Ventas por Año')

# Quitar la etiqueta del eje Y
plt.ylabel('')  # Elimina la etiqueta del eje Y

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar 300 alturas aleatorias entre 150 y 190 cm
alturas = np.random.randint(150, 191, size=50)

# Pintar el histograma
plt.hist(alturas, bins=10, color='skyblue', edgecolor='black')

# Título y etiquetas
plt.title('Histograma de Alturas Aleatorias')
plt.xlabel('Altura (cm)')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
