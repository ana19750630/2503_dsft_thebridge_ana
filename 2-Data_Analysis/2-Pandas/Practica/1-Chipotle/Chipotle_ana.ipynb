# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep="\t")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo["item_price"]= chipo["item_price"].str.replace("$","").astype(float)
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %%
chipo["item_price"].hist()
# Out:
# <Axes: >

# %%
chipo["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo["item_price"].max()
maximo = chipo["item_price"].max()
maximo
# Out:
# np.float64(44.25)

# %%
chipo[chipo["item_price"] == maximo]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
str(chipo[chipo["item_price"] ==chipo["item_price"].max()]["item_name"].values[0])
# Out:
# 'Chips and Fresh Tomato Salsa'

# %%
chipo["item_name"].value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# Chips and Tomatillo Red Chili Salsa       48
# Chicken Crispy Tacos                      47
# Chips and Tomatillo Green Chili Salsa     43
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        35
# Chips and Tomatillo-Green Chili Salsa     31
# Steak Salad Bowl                          29
# Nantucket Nectar                          27
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        22
# Izze                                      20
# Chips and Tomatillo-Red Chili Salsa       20
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Chicken Salad                              9
# Veggie Soft Tacos                          7
# Carnitas Crispy Tacos                      7
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Steak Salad                                4
# Crispy Tacos                               2
# Bowl                                       2
# Salad                                      2
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Carnitas Salad                             1
# Name: count, dtype: int64

# %%
chipo[chipo["item_name"]=="Chicken Bowl"]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...        8.75
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...        8.75
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]        8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
#
# [726 rows x 5 columns]

# %%
chipo["unit_price"] = chipo["item_price"]/ chipo["quantity"]
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
#       unit_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4           8.49
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 6 columns]

# %%
len(chipo[chipo["item_name"]=="Chicken Bowl"])
# Out:
# 726

# %%
chipo["order_id"].value_counts()
# Out:
# order_id
# 926     23
# 1483    14
# 205     12
# 759     11
# 691     11
#         ..
# 60       1
# 66       1
# 72       1
# 1813     1
# 2        1
# Name: count, Length: 1834, dtype: int64

# %%
chipo["item_name"].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
#        'Burrito', 'Crispy Tacos', 'Carnitas Crispy Tacos', 'Steak Salad',
#        'Chips and Mild Fresh Tomato Salsa', 'Veggie Soft Tacos',
#        'Carnitas Salad Bowl', 'Barbacoa Salad Bowl', 'Salad',
#        'Veggie Crispy Tacos', 'Veggie Salad', 'Carnitas Salad'],
#       dtype=object)

# %%
chipo[chipo["item_name"]=="Chicken Burrito"]
# Out:
#       order_id  quantity        item_name  \
# 16           8         1  Chicken Burrito
# 17           9         1  Chicken Burrito
# 23          12         1  Chicken Burrito
# 29          15         1  Chicken Burrito
# 45          21         1  Chicken Burrito
# ...        ...       ...              ...
# 4556      1811         1  Chicken Burrito
# 4558      1812         1  Chicken Burrito
# 4559      1812         1  Chicken Burrito
# 4566      1816         1  Chicken Burrito
# 4569      1817         1  Chicken Burrito
#
#                                      choice_description  item_price  \
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...        8.49
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# 29    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 45    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       10.98
# ...                                                 ...         ...
# 4556  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...       11.25
# 4558  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 4559  [Tomatillo Red Chili Salsa, [Rice, Cheese, Gua...       11.25
# 4566  [Roasted Chili Corn Salsa, [Pinto Beans, Chees...        8.75
# 4569    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]        8.75
#
#       total_price
# 16           8.49
# 17           8.49
# 23          10.98
# 29           8.49
# 45          10.98
# ...           ...
# 4556        11.25
# 4558         8.75
# 4559        11.25
# 4566         8.75
# 4569         8.75
#
# [553 rows x 6 columns]

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo[chipo["item_price"]>10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...                                                 ...         ...
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...       11.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
#
#       unit_price
# 4           8.49
# 5          10.98
# 7          11.75
# 13         11.25
# 23         10.98
# ...          ...
# 4610       11.75
# 4611       11.25
# 4617       11.75
# 4618       11.75
# 4619       11.25
#
# [1130 rows x 6 columns]

# %%
chipo_mayor10 = chipo[chipo["item_price"]>10]
chipo_mayor10
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...                                                 ...         ...
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...       11.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
#
#       unit_price
# 4           8.49
# 5          10.98
# 7          11.75
# 13         11.25
# 23         10.98
# ...          ...
# 4610       11.75
# 4611       11.25
# 4617       11.75
# 4618       11.75
# 4619       11.25
#
# [1130 rows x 6 columns]

# %%
chipo_mayor10["item_name"].unique()
# Out:
# array(['Chicken Bowl', 'Steak Burrito', 'Chicken Burrito',
#        'Barbacoa Bowl', 'Veggie Burrito', 'Veggie Bowl',
#        'Chicken Soft Tacos', 'Steak Bowl', 'Carnitas Burrito',
#        'Carnitas Bowl', 'Barbacoa Burrito', 'Chicken Salad Bowl',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chicken Crispy Tacos', 'Chicken Salad', 'Steak Salad Bowl',
#        'Bowl', 'Veggie Soft Tacos', 'Barbacoa Soft Tacos',
#        'Carnitas Crispy Tacos', 'Carnitas Salad Bowl',
#        'Barbacoa Salad Bowl', 'Chips and Fresh Tomato Salsa',
#        'Steak Soft Tacos', 'Carnitas Soft Tacos', 'Steak Crispy Tacos',
#        'Chips and Guacamole', '6 Pack Soft Drink', 'Bottled Water',
#        'Side of Chips'], dtype=object)

# %%
chipo[chipo["item_price"]>10]["item_price"].sum()
# Out:
# np.float64(14003.54)

# %% [markdown]
# ### Step 4.1: Y cuántos pedidos se han hecho con un producto de más de 10$? Es lo mismo?

# %%
chipo["total_price"]=chipo["item_price"] * chipo["quantity"]
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
#       total_price
# 0            2.39
# 1            3.39
# 2            3.39
# 3            2.39
# 4           33.96
# ...           ...
# 4617        11.75
# 4618        11.75
# 4619        11.25
# 4620         8.75
# 4621         8.75
#
# [4622 rows x 6 columns]

# %%
numeros_pedidos = chipo[chipo["item_price"] > 10]["item_price"].count()
numeros_pedidos
# Out:
# np.int64(1130)

# %% [markdown]
# ### Step 4.2: Y cuántos pedidos se han hecho de más de 10$? Es lo mismo?

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
#       unit_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4           8.49
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 6 columns]

# %%
chipo[["order_id", "item_price"]]
# Out:
#       order_id  item_price
# 0            1        2.39
# 1            1        3.39
# 2            1        3.39
# 3            1        2.39
# 4            2       16.98
# ...        ...         ...
# 4617      1833       11.75
# 4618      1833       11.75
# 4619      1834       11.25
# 4620      1834        8.75
# 4621      1834        8.75
#
# [4622 rows x 2 columns]

# %%
chipo["order_id"].unique()
# Out:
# array([   1,    2,    3, ..., 1832, 1833, 1834], shape=(1834,))

# %%
ordenes_unicas = chipo["order_id"].unique()
for id in ordenes_unicas:
    order_df = chipo[chipo["order_id"]==id]
    total = order_df["item_price"].sum
    print(f"orden {id}, total:{total}$")
# Out:
# orden 1, total:<bound method Series.sum of 0    2.39
# 1    3.39
# 2    3.39
# 3    2.39
# Name: item_price, dtype: float64>$
# orden 2, total:<bound method Series.sum of 4    16.98
# Name: item_price, dtype: float64>$
# orden 3, total:<bound method Series.sum of 5    10.98
# 6     1.69
# Name: item_price, dtype: float64>$
# orden 4, total:<bound method Series.sum of 7    11.75
# 8     9.25
# Name: item_price, dtype: float64>$
# orden 5, total:<bound method Series.sum of 9     9.25
# 10    4.45
# Name: item_price, dtype: float64>$
# orden 6, total:<bound method Series.sum of 11    8.75
# 12    8.75
# Name: item_price, dtype: float64>$
# orden 7, total:<bound method Series.sum of 13    11.25
# 14     4.45
# Name: item_price, dtype: float64>$
# orden 8, total:<bound method Series.sum of 15    2.39
# 16    8.49
# Name: item_price, dtype: float64>$
# orden 9, total:<bound method Series.sum of 17    8.49
# 18    2.18
# Name: item_price, dtype: float64>$
# orden 10, total:<bound method Series.sum of 19    8.75
# 20    4.45
# Name: item_price, dtype: float64>$
# orden 11, total:<bound method Series.sum of 21    8.99
# 22    3.39
# Name: item_price, dtype: float64>$
# orden 12, total:<bound method Series.sum of 23    10.98
# 24     3.39
# Name: item_price, dtype: float64>$
# orden 13, total:<bound method Series.sum of 25    2.39
# 26    8.49
# Name: item_price, dtype: float64>$
# orden 14, total:<bound method Series.sum of 27    8.99
# 28    1.09
# Name: item_price, dtype: float64>$
# orden 15, total:<bound method Series.sum of 29    8.49
# 30    2.39
# Name: item_price, dtype: float64>$
# orden 16, total:<bound method Series.sum of 31    8.99
# 32    1.69
# Name: item_price, dtype: float64>$
# orden 17, total:<bound method Series.sum of 33    8.99
# 34    1.09
# Name: item_price, dtype: float64>$
# orden 18, total:<bound method Series.sum of 35    8.75
# 36    8.75
# 37    4.45
# 38    2.95
# Name: item_price, dtype: float64>$
# orden 19, total:<bound method Series.sum of 39    11.75
# 40     2.15
# Name: item_price, dtype: float64>$
# orden 20, total:<bound method Series.sum of 41     4.45
# 42    11.25
# 43    11.75
# 44     8.75
# Name: item_price, dtype: float64>$
# orden 21, total:<bound method Series.sum of 45    10.98
# 46     8.99
# 47     3.39
# Name: item_price, dtype: float64>$
# orden 22, total:<bound method Series.sum of 48    8.99
# 49    3.99
# Name: item_price, dtype: float64>$
# orden 23, total:<bound method Series.sum of 50    8.99
# 51    2.18
# Name: item_price, dtype: float64>$
# orden 24, total:<bound method Series.sum of 52    10.98
# 53     1.09
# Name: item_price, dtype: float64>$
# orden 25, total:<bound method Series.sum of 54    8.99
# 55    2.39
# Name: item_price, dtype: float64>$
# orden 26, total:<bound method Series.sum of 56     9.25
# 57    11.25
# Name: item_price, dtype: float64>$
# orden 27, total:<bound method Series.sum of 58    11.75
# 59     2.15
# Name: item_price, dtype: float64>$
# orden 28, total:<bound method Series.sum of 60     4.45
# 61     9.25
# 62    11.25
# 63     8.75
# Name: item_price, dtype: float64>$
# orden 29, total:<bound method Series.sum of 64    8.99
# 65    8.99
# Name: item_price, dtype: float64>$
# orden 30, total:<bound method Series.sum of 66     3.39
# 67     8.99
# 68    10.98
# Name: item_price, dtype: float64>$
# orden 31, total:<bound method Series.sum of 69    8.99
# 70    1.69
# Name: item_price, dtype: float64>$
# orden 32, total:<bound method Series.sum of 71    8.99
# 72    3.99
# Name: item_price, dtype: float64>$
# orden 33, total:<bound method Series.sum of 73    8.75
# 74    4.45
# Name: item_price, dtype: float64>$
# orden 34, total:<bound method Series.sum of 75    8.75
# 76    8.75
# 77    2.15
# 78    8.75
# Name: item_price, dtype: float64>$
# orden 35, total:<bound method Series.sum of 79    11.25
# 80     2.15
# Name: item_price, dtype: float64>$
# orden 36, total:<bound method Series.sum of 81    9.25
# 82    8.75
# Name: item_price, dtype: float64>$
# orden 37, total:<bound method Series.sum of 83    8.75
# 84    9.25
# Name: item_price, dtype: float64>$
# orden 38, total:<bound method Series.sum of 85    8.49
# 86    8.99
# 87    1.09
# Name: item_price, dtype: float64>$
# orden 39, total:<bound method Series.sum of 88    9.25
# 89    2.95
# Name: item_price, dtype: float64>$
# orden 40, total:<bound method Series.sum of 90    11.75
# 91    11.75
# 92     9.25
# Name: item_price, dtype: float64>$
# orden 41, total:<bound method Series.sum of 93    11.75
# 94     4.45
# Name: item_price, dtype: float64>$
# orden 42, total:<bound method Series.sum of 95    9.25
# 96    4.45
# Name: item_price, dtype: float64>$
# orden 43, total:<bound method Series.sum of 97    11.75
# 98     8.75
# Name: item_price, dtype: float64>$
# orden 44, total:<bound method Series.sum of 99     8.75
# 100    4.45
# Name: item_price, dtype: float64>$
# orden 45, total:<bound method Series.sum of 101    8.99
# 102    8.99
# 103    3.99
# Name: item_price, dtype: float64>$
# orden 46, total:<bound method Series.sum of 104    8.49
# 105    3.39
# Name: item_price, dtype: float64>$
# orden 47, total:<bound method Series.sum of 106    8.99
# 107    1.09
# Name: item_price, dtype: float64>$
# orden 48, total:<bound method Series.sum of 108    9.25
# 109    4.45
# Name: item_price, dtype: float64>$
# orden 49, total:<bound method Series.sum of 110    8.75
# 111    2.95
# 112    4.45
# Name: item_price, dtype: float64>$
# orden 50, total:<bound method Series.sum of 113    2.39
# 114    8.49
# Name: item_price, dtype: float64>$
# orden 51, total:<bound method Series.sum of 115    8.99
# 116    8.49
# 117    1.09
# Name: item_price, dtype: float64>$
# orden 52, total:<bound method Series.sum of 118    8.99
# 119    3.99
# Name: item_price, dtype: float64>$
# orden 53, total:<bound method Series.sum of 120    8.75
# 121    9.25
# 122    4.45
# Name: item_price, dtype: float64>$
# orden 54, total:<bound method Series.sum of 123    11.25
# 124     4.45
# Name: item_price, dtype: float64>$
# orden 55, total:<bound method Series.sum of 125    8.99
# 126    1.09
# Name: item_price, dtype: float64>$
# orden 56, total:<bound method Series.sum of 127    9.25
# 128    2.95
# 129    4.45
# Name: item_price, dtype: float64>$
# orden 57, total:<bound method Series.sum of 130    11.75
# 131     4.45
# Name: item_price, dtype: float64>$
# orden 58, total:<bound method Series.sum of 132    8.49
# 133    2.39
# Name: item_price, dtype: float64>$
# orden 59, total:<bound method Series.sum of 134    10.98
# Name: item_price, dtype: float64>$
# orden 60, total:<bound method Series.sum of 135    22.5
# Name: item_price, dtype: float64>$
# orden 61, total:<bound method Series.sum of 136    11.75
# 137     4.45
# Name: item_price, dtype: float64>$
# orden 62, total:<bound method Series.sum of 138    11.25
# 139     4.45
# Name: item_price, dtype: float64>$
# orden 63, total:<bound method Series.sum of 140    11.25
# 141     4.45
# Name: item_price, dtype: float64>$
# orden 64, total:<bound method Series.sum of 142    11.25
# 143    11.25
# Name: item_price, dtype: float64>$
# orden 65, total:<bound method Series.sum of 144    11.75
# 145     9.25
# 146     4.45
# Name: item_price, dtype: float64>$
# orden 66, total:<bound method Series.sum of 147    11.48
# Name: item_price, dtype: float64>$
# orden 67, total:<bound method Series.sum of 148    17.98
# 149     1.69
# Name: item_price, dtype: float64>$
# orden 68, total:<bound method Series.sum of 150    17.50
# 151     4.45
# Name: item_price, dtype: float64>$
# orden 69, total:<bound method Series.sum of 152    8.49
# 153    2.39
# Name: item_price, dtype: float64>$
# orden 70, total:<bound method Series.sum of 154    17.50
# 155     4.45
# Name: item_price, dtype: float64>$
# orden 71, total:<bound method Series.sum of 156     4.45
# 157    11.25
# 158    11.75
# Name: item_price, dtype: float64>$
# orden 72, total:<bound method Series.sum of 159    10.98
# Name: item_price, dtype: float64>$
# orden 73, total:<bound method Series.sum of 160     8.49
# 161    10.98
# 162     2.18
# Name: item_price, dtype: float64>$
# orden 74, total:<bound method Series.sum of 163    11.48
# 164     8.49
# 165     2.39
# Name: item_price, dtype: float64>$
# orden 75, total:<bound method Series.sum of 166     4.45
# 167    11.25
# 168    11.75
# 169     8.75
# Name: item_price, dtype: float64>$
# orden 76, total:<bound method Series.sum of 170    8.49
# 171    2.18
# Name: item_price, dtype: float64>$
# orden 77, total:<bound method Series.sum of 172    8.49
# 173    3.39
# Name: item_price, dtype: float64>$
# orden 78, total:<bound method Series.sum of 174    8.49
# 175    8.99
# Name: item_price, dtype: float64>$
# orden 79, total:<bound method Series.sum of 176    10.98
# Name: item_price, dtype: float64>$
# orden 80, total:<bound method Series.sum of 177    11.48
# Name: item_price, dtype: float64>$
# orden 81, total:<bound method Series.sum of 178    8.49
# 179    1.09
# 180    1.09
# Name: item_price, dtype: float64>$
# orden 82, total:<bound method Series.sum of 181    9.25
# 182    8.75
# 183    2.95
# Name: item_price, dtype: float64>$
# orden 83, total:<bound method Series.sum of 184     9.25
# 185     4.45
# 186    11.25
# Name: item_price, dtype: float64>$
# orden 84, total:<bound method Series.sum of 187    11.48
# 188     8.49
# 189     8.49
# Name: item_price, dtype: float64>$
# orden 85, total:<bound method Series.sum of 190    8.99
# 191    2.39
# Name: item_price, dtype: float64>$
# orden 86, total:<bound method Series.sum of 192    11.25
# 193     8.75
# 194     2.95
# Name: item_price, dtype: float64>$
# orden 87, total:<bound method Series.sum of 195    1.09
# 196    8.99
# Name: item_price, dtype: float64>$
# orden 88, total:<bound method Series.sum of 197    8.49
# 198    2.39
# Name: item_price, dtype: float64>$
# orden 89, total:<bound method Series.sum of 199    10.98
# 200     1.09
# 201     3.99
# Name: item_price, dtype: float64>$
# orden 90, total:<bound method Series.sum of 202    11.25
# 203     8.75
# Name: item_price, dtype: float64>$
# orden 91, total:<bound method Series.sum of 204    8.49
# 205    3.39
# Name: item_price, dtype: float64>$
# orden 92, total:<bound method Series.sum of 206    8.75
# 207    9.25
# 208    2.15
# Name: item_price, dtype: float64>$
# orden 93, total:<bound method Series.sum of 209    11.25
# 210    11.25
# 211    11.25
# 212     4.45
# Name: item_price, dtype: float64>$
# orden 94, total:<bound method Series.sum of 213    22.5
# Name: item_price, dtype: float64>$
# orden 95, total:<bound method Series.sum of 214     4.45
# 215    11.75
# Name: item_price, dtype: float64>$
# orden 96, total:<bound method Series.sum of 216     8.75
# 217    17.50
# 218     8.75
# Name: item_price, dtype: float64>$
# orden 97, total:<bound method Series.sum of 219    9.25
# 220    8.75
# 221    2.15
# Name: item_price, dtype: float64>$
# orden 98, total:<bound method Series.sum of 222    9.25
# 223    4.30
# 224    8.75
# Name: item_price, dtype: float64>$
# orden 99, total:<bound method Series.sum of 225    11.25
# 226     2.15
# Name: item_price, dtype: float64>$
# orden 100, total:<bound method Series.sum of 227    8.99
# 228    1.09
# Name: item_price, dtype: float64>$
# orden 101, total:<bound method Series.sum of 229    8.99
# 230    3.99
# Name: item_price, dtype: float64>$
# orden 102, total:<bound method Series.sum of 231    8.75
# 232    2.95
# 233    2.95
# Name: item_price, dtype: float64>$
# orden 103, total:<bound method Series.sum of 234    11.75
# 235     5.90
# 236     9.25
# 237     9.25
# 238    11.75
# Name: item_price, dtype: float64>$
# orden 104, total:<bound method Series.sum of 239    9.25
# 240    2.95
# Name: item_price, dtype: float64>$
# orden 105, total:<bound method Series.sum of 241    17.5
# Name: item_price, dtype: float64>$
# orden 106, total:<bound method Series.sum of 242    8.75
# 243    9.25
# Name: item_price, dtype: float64>$
# orden 107, total:<bound method Series.sum of 244    10.98
# Name: item_price, dtype: float64>$
# orden 108, total:<bound method Series.sum of 245    8.99
# 246    1.09
# 247    1.09
# 248    1.09
# 249    8.99
# Name: item_price, dtype: float64>$
# orden 109, total:<bound method Series.sum of 250    10.98
# 251     1.09
# Name: item_price, dtype: float64>$
# orden 110, total:<bound method Series.sum of 252    8.75
# 253    8.75
# 254    9.25
# 255    9.25
# Name: item_price, dtype: float64>$
# orden 111, total:<bound method Series.sum of 256    8.75
# 257    8.75
# Name: item_price, dtype: float64>$
# orden 112, total:<bound method Series.sum of 258    8.99
# 259    8.99
# Name: item_price, dtype: float64>$
# orden 113, total:<bound method Series.sum of 260    8.99
# 261    1.09
# Name: item_price, dtype: float64>$
# orden 114, total:<bound method Series.sum of 262    11.75
# 263     1.25
# Name: item_price, dtype: float64>$
# orden 115, total:<bound method Series.sum of 264    8.99
# 265    2.39
# Name: item_price, dtype: float64>$
# orden 116, total:<bound method Series.sum of 266    9.25
# 267    2.95
# Name: item_price, dtype: float64>$
# orden 117, total:<bound method Series.sum of 268    8.99
# 269    3.99
# Name: item_price, dtype: float64>$
# orden 118, total:<bound method Series.sum of 270    8.49
# 271    2.39
# Name: item_price, dtype: float64>$
# orden 119, total:<bound method Series.sum of 272    8.49
# 273    8.49
# Name: item_price, dtype: float64>$
# orden 120, total:<bound method Series.sum of 274    8.49
# 275    1.69
# Name: item_price, dtype: float64>$
# orden 121, total:<bound method Series.sum of 276    8.49
# 277    3.99
# Name: item_price, dtype: float64>$
# orden 122, total:<bound method Series.sum of 278    8.99
# 279    1.69
# 280    1.09
# Name: item_price, dtype: float64>$
# orden 123, total:<bound method Series.sum of 281    23.78
# Name: item_price, dtype: float64>$
# orden 124, total:<bound method Series.sum of 282    17.50
# 283     2.15
# 284     8.75
# Name: item_price, dtype: float64>$
# orden 125, total:<bound method Series.sum of 285    9.25
# 286    9.25
# 287    8.75
# 288    4.45
# Name: item_price, dtype: float64>$
# orden 126, total:<bound method Series.sum of 289     8.75
# 290    11.25
# Name: item_price, dtype: float64>$
# orden 127, total:<bound method Series.sum of 291    11.25
# 292     1.25
# Name: item_price, dtype: float64>$
# orden 128, total:<bound method Series.sum of 293     9.25
# 294     4.45
# 295    11.25
# Name: item_price, dtype: float64>$
# orden 129, total:<bound method Series.sum of 296    11.75
# 297    11.75
# 298     6.49
# Name: item_price, dtype: float64>$
# orden 130, total:<bound method Series.sum of 299    8.99
# 300    2.39
# Name: item_price, dtype: float64>$
# orden 131, total:<bound method Series.sum of 301    8.49
# 302    2.39
# Name: item_price, dtype: float64>$
# orden 132, total:<bound method Series.sum of 303    11.25
# 304     8.75
# 305     2.15
# Name: item_price, dtype: float64>$
# orden 133, total:<bound method Series.sum of 306    8.99
# 307    1.69
# Name: item_price, dtype: float64>$
# orden 134, total:<bound method Series.sum of 308     8.75
# 309    11.25
# 310     2.15
# Name: item_price, dtype: float64>$
# orden 135, total:<bound method Series.sum of 311    4.45
# 312    8.75
# Name: item_price, dtype: float64>$
# orden 136, total:<bound method Series.sum of 313    8.49
# 314    8.99
# Name: item_price, dtype: float64>$
# orden 137, total:<bound method Series.sum of 315    17.5
# Name: item_price, dtype: float64>$
# orden 138, total:<bound method Series.sum of 316    8.49
# 317    1.09
# 318    1.09
# Name: item_price, dtype: float64>$
# orden 139, total:<bound method Series.sum of 319    8.75
# 320    1.25
# 321    2.15
# Name: item_price, dtype: float64>$
# orden 140, total:<bound method Series.sum of 322    11.08
# Name: item_price, dtype: float64>$
# orden 141, total:<bound method Series.sum of 323    8.49
# 324    8.49
# Name: item_price, dtype: float64>$
# orden 142, total:<bound method Series.sum of 325    8.99
# 326    2.39
# Name: item_price, dtype: float64>$
# orden 143, total:<bound method Series.sum of 327    8.75
# 328    2.15
# 329    1.50
# Name: item_price, dtype: float64>$
# orden 144, total:<bound method Series.sum of 330    11.25
# 331     2.15
# Name: item_price, dtype: float64>$
# orden 145, total:<bound method Series.sum of 332    8.49
# 333    8.49
# Name: item_price, dtype: float64>$
# orden 146, total:<bound method Series.sum of 334    11.75
# 335     9.25
# Name: item_price, dtype: float64>$
# orden 147, total:<bound method Series.sum of 336    11.75
# 337     1.25
# Name: item_price, dtype: float64>$
# orden 148, total:<bound method Series.sum of 338    11.25
# 339     8.75
# 340     4.45
# 341     6.49
# Name: item_price, dtype: float64>$
# orden 149, total:<bound method Series.sum of 342     9.25
# 343     2.95
# 344    11.25
# 345     4.45
# 346     1.25
# 347     1.25
# Name: item_price, dtype: float64>$
# orden 150, total:<bound method Series.sum of 348    8.49
# 349    2.39
# 350    2.18
# Name: item_price, dtype: float64>$
# orden 151, total:<bound method Series.sum of 351    8.49
# 352    2.18
# Name: item_price, dtype: float64>$
# orden 152, total:<bound method Series.sum of 353    22.16
# Name: item_price, dtype: float64>$
# orden 153, total:<bound method Series.sum of 354    17.5
# Name: item_price, dtype: float64>$
# orden 154, total:<bound method Series.sum of 355    8.75
# 356    2.95
# 357    6.49
# Name: item_price, dtype: float64>$
# orden 155, total:<bound method Series.sum of 358    8.99
# 359    3.39
# 360    3.39
# Name: item_price, dtype: float64>$
# orden 156, total:<bound method Series.sum of 361    8.99
# 362    8.49
# Name: item_price, dtype: float64>$
# orden 157, total:<bound method Series.sum of 363    11.25
# 364     2.15
# Name: item_price, dtype: float64>$
# orden 158, total:<bound method Series.sum of 365    11.25
# 366     2.95
# Name: item_price, dtype: float64>$
# orden 159, total:<bound method Series.sum of 367    11.25
# 368     1.25
# Name: item_price, dtype: float64>$
# orden 160, total:<bound method Series.sum of 369    8.99
# 370    1.09
# Name: item_price, dtype: float64>$
# orden 161, total:<bound method Series.sum of 371    8.75
# 372    8.75
# Name: item_price, dtype: float64>$
# orden 162, total:<bound method Series.sum of 373    9.25
# 374    2.95
# Name: item_price, dtype: float64>$
# orden 163, total:<bound method Series.sum of 375    11.75
# 376     1.50
# Name: item_price, dtype: float64>$
# orden 164, total:<bound method Series.sum of 377    8.99
# 378    1.09
# Name: item_price, dtype: float64>$
# orden 165, total:<bound method Series.sum of 379    11.25
# 380     1.25
# 381     1.25
# Name: item_price, dtype: float64>$
# orden 166, total:<bound method Series.sum of 382    11.25
# 383    11.75
# 384     2.15
# Name: item_price, dtype: float64>$
# orden 167, total:<bound method Series.sum of 385    8.99
# 386    1.69
# Name: item_price, dtype: float64>$
# orden 168, total:<bound method Series.sum of 387    11.75
# 388     6.49
# Name: item_price, dtype: float64>$
# orden 169, total:<bound method Series.sum of 389    8.75
# 390    9.25
# Name: item_price, dtype: float64>$
# orden 170, total:<bound method Series.sum of 391    11.25
# 392     4.45
# 393     1.25
# Name: item_price, dtype: float64>$
# orden 171, total:<bound method Series.sum of 394    11.25
# 395     4.45
# Name: item_price, dtype: float64>$
# orden 172, total:<bound method Series.sum of 396    8.49
# 397    8.99
# Name: item_price, dtype: float64>$
# orden 173, total:<bound method Series.sum of 398    8.49
# 399    8.99
# Name: item_price, dtype: float64>$
# orden 174, total:<bound method Series.sum of 400    11.25
# 401     1.25
# Name: item_price, dtype: float64>$
# orden 175, total:<bound method Series.sum of 402    11.75
# 403     1.25
# Name: item_price, dtype: float64>$
# orden 176, total:<bound method Series.sum of 404    11.75
# 405     9.25
# 406     4.45
# Name: item_price, dtype: float64>$
# orden 177, total:<bound method Series.sum of 407    11.25
# 408     2.15
# Name: item_price, dtype: float64>$
# orden 178, total:<bound method Series.sum of 409    32.94
# Name: item_price, dtype: float64>$
# orden 179, total:<bound method Series.sum of 410     1.25
# 411    11.25
# Name: item_price, dtype: float64>$
# orden 180, total:<bound method Series.sum of 412    11.48
# 413     1.69
# 414     1.09
# Name: item_price, dtype: float64>$
# orden 181, total:<bound method Series.sum of 415    17.5
# Name: item_price, dtype: float64>$
# orden 182, total:<bound method Series.sum of 416    4.45
# 417    6.49
# 418    9.25
# Name: item_price, dtype: float64>$
# orden 183, total:<bound method Series.sum of 419    8.75
# 420    9.25
# Name: item_price, dtype: float64>$
# orden 184, total:<bound method Series.sum of 421    9.25
# 422    8.75
# 423    8.75
# 424    2.15
# 425    2.95
# Name: item_price, dtype: float64>$
# orden 185, total:<bound method Series.sum of 426    17.5
# Name: item_price, dtype: float64>$
# orden 186, total:<bound method Series.sum of 427    10.98
# 428    11.48
# 429    11.48
# 430     3.39
# Name: item_price, dtype: float64>$
# orden 187, total:<bound method Series.sum of 431    8.99
# 432    1.69
# Name: item_price, dtype: float64>$
# orden 188, total:<bound method Series.sum of 433    8.99
# 434    1.09
# Name: item_price, dtype: float64>$
# orden 189, total:<bound method Series.sum of 435    10.98
# 436     3.39
# Name: item_price, dtype: float64>$
# orden 190, total:<bound method Series.sum of 437    8.99
# 438    1.09
# Name: item_price, dtype: float64>$
# orden 191, total:<bound method Series.sum of 439    9.25
# 440    8.75
# Name: item_price, dtype: float64>$
# orden 192, total:<bound method Series.sum of 441    11.25
# 442     4.45
# 443     2.95
# 444     9.25
# Name: item_price, dtype: float64>$
# orden 193, total:<bound method Series.sum of 445    22.2
# Name: item_price, dtype: float64>$
# orden 194, total:<bound method Series.sum of 446    8.49
# 447    8.99
# Name: item_price, dtype: float64>$
# orden 195, total:<bound method Series.sum of 448     8.75
# 449     8.75
# 450    11.75
# 451     8.75
# 452    11.25
# 453     9.25
# 454    11.25
# 455    11.25
# Name: item_price, dtype: float64>$
# orden 196, total:<bound method Series.sum of 456     8.75
# 457    11.25
# 458     2.95
# 459     1.25
# Name: item_price, dtype: float64>$
# orden 197, total:<bound method Series.sum of 460    8.49
# 461    1.69
# Name: item_price, dtype: float64>$
# orden 198, total:<bound method Series.sum of 462    11.75
# 463    11.25
# Name: item_price, dtype: float64>$
# orden 199, total:<bound method Series.sum of 464    8.75
# 465    8.75
# 466    4.45
# Name: item_price, dtype: float64>$
# orden 200, total:<bound method Series.sum of 467    8.49
# 468    3.99
# Name: item_price, dtype: float64>$
# orden 201, total:<bound method Series.sum of 469    8.49
# 470    3.99
# Name: item_price, dtype: float64>$
# orden 202, total:<bound method Series.sum of 471    11.48
# 472     1.69
# 473     1.09
# Name: item_price, dtype: float64>$
# orden 203, total:<bound method Series.sum of 474    11.25
# 475     1.50
# Name: item_price, dtype: float64>$
# orden 204, total:<bound method Series.sum of 476    10.58
# 477     1.69
# Name: item_price, dtype: float64>$
# orden 205, total:<bound method Series.sum of 478     9.25
# 479    11.25
# 480     8.75
# 481     9.25
# 482    11.25
# 483    11.25
# 484     8.75
# 485    11.75
# 486     8.75
# 487     8.75
# 488     8.75
# 489     2.15
# Name: item_price, dtype: float64>$
# orden 206, total:<bound method Series.sum of 490    11.25
# 491    11.75
# 492     2.50
# 493     4.45
# Name: item_price, dtype: float64>$
# orden 207, total:<bound method Series.sum of 494     9.25
# 495     4.45
# 496    11.25
# Name: item_price, dtype: float64>$
# orden 208, total:<bound method Series.sum of 497    8.49
# 498    3.99
# Name: item_price, dtype: float64>$
# orden 209, total:<bound method Series.sum of 499    9.25
# 500    9.25
# Name: item_price, dtype: float64>$
# orden 210, total:<bound method Series.sum of 501    11.25
# 502     9.25
# Name: item_price, dtype: float64>$
# orden 211, total:<bound method Series.sum of 503    11.75
# 504    11.25
# Name: item_price, dtype: float64>$
# orden 212, total:<bound method Series.sum of 505     1.25
# 506    23.50
# 507     1.25
# Name: item_price, dtype: float64>$
# orden 213, total:<bound method Series.sum of 508    8.99
# 509    8.49
# Name: item_price, dtype: float64>$
# orden 214, total:<bound method Series.sum of 510    7.4
# 511    7.4
# Name: item_price, dtype: float64>$
# orden 215, total:<bound method Series.sum of 512    8.75
# 513    1.25
# 514    4.45
# 515    8.75
# 516    2.15
# Name: item_price, dtype: float64>$
# orden 216, total:<bound method Series.sum of 517    8.75
# 518    4.45
# Name: item_price, dtype: float64>$
# orden 217, total:<bound method Series.sum of 519    7.4
# 520    7.4
# 521    7.4
# Name: item_price, dtype: float64>$
# orden 218, total:<bound method Series.sum of 522    8.99
# 523    3.99
# Name: item_price, dtype: float64>$
# orden 219, total:<bound method Series.sum of 524    8.99
# 525    1.69
# Name: item_price, dtype: float64>$
# orden 220, total:<bound method Series.sum of 526    8.75
# 527    8.75
# Name: item_price, dtype: float64>$
# orden 221, total:<bound method Series.sum of 528    8.75
# 529    8.75
# Name: item_price, dtype: float64>$
# orden 222, total:<bound method Series.sum of 530    11.25
# 531    11.25
# 532     2.95
# Name: item_price, dtype: float64>$
# orden 223, total:<bound method Series.sum of 533     8.75
# 534    18.50
# Name: item_price, dtype: float64>$
# orden 224, total:<bound method Series.sum of 535    8.49
# 536    3.99
# Name: item_price, dtype: float64>$
# orden 225, total:<bound method Series.sum of 537    2.95
# 538    9.25
# 539    9.25
# 540    3.00
# 541    1.25
# Name: item_price, dtype: float64>$
# orden 226, total:<bound method Series.sum of 542    8.75
# 543    9.25
# 544    4.45
# Name: item_price, dtype: float64>$
# orden 227, total:<bound method Series.sum of 545     8.75
# 546    11.25
# 547     4.45
# Name: item_price, dtype: float64>$
# orden 228, total:<bound method Series.sum of 548    10.98
# Name: item_price, dtype: float64>$
# orden 229, total:<bound method Series.sum of 549    22.16
# Name: item_price, dtype: float64>$
# orden 230, total:<bound method Series.sum of 550    4.45
# 551    8.75
# 552    9.25
# 553    6.49
# 554    9.25
# Name: item_price, dtype: float64>$
# orden 231, total:<bound method Series.sum of 555    11.25
# 556     8.75
# 557     9.25
# 558     2.15
# 559     9.25
# 560     4.45
# Name: item_price, dtype: float64>$
# orden 232, total:<bound method Series.sum of 561    9.25
# 562    2.95
# Name: item_price, dtype: float64>$
# orden 233, total:<bound method Series.sum of 563    9.25
# 564    8.75
# 565    9.25
# 566    1.25
# 567    1.25
# Name: item_price, dtype: float64>$
# orden 234, total:<bound method Series.sum of 568    8.75
# 569    8.75
# 570    9.25
# 571    4.45
# Name: item_price, dtype: float64>$
# orden 235, total:<bound method Series.sum of 572    11.75
# 573    11.75
# 574    11.75
# Name: item_price, dtype: float64>$
# orden 236, total:<bound method Series.sum of 575    9.25
# 576    9.25
# Name: item_price, dtype: float64>$
# orden 237, total:<bound method Series.sum of 577    16.98
# 578     2.39
# 579     3.39
# 580     3.39
# Name: item_price, dtype: float64>$
# orden 238, total:<bound method Series.sum of 581     9.25
# 582    11.75
# Name: item_price, dtype: float64>$
# orden 239, total:<bound method Series.sum of 583    11.25
# 584     2.15
# Name: item_price, dtype: float64>$
# orden 240, total:<bound method Series.sum of 585    8.75
# 586    9.25
# 587    4.45
# Name: item_price, dtype: float64>$
# orden 241, total:<bound method Series.sum of 588    10.98
# Name: item_price, dtype: float64>$
# orden 242, total:<bound method Series.sum of 589    11.25
# 590     9.25
# Name: item_price, dtype: float64>$
# orden 243, total:<bound method Series.sum of 591    22.5
# Name: item_price, dtype: float64>$
# orden 244, total:<bound method Series.sum of 592    9.25
# 593    2.95
# 594    1.50
# Name: item_price, dtype: float64>$
# orden 245, total:<bound method Series.sum of 595    11.48
# Name: item_price, dtype: float64>$
# orden 246, total:<bound method Series.sum of 596    8.49
# 597    1.69
# Name: item_price, dtype: float64>$
# orden 247, total:<bound method Series.sum of 598    8.49
# 599    8.49
# 600    8.49
# 601    6.78
# Name: item_price, dtype: float64>$
# orden 248, total:<bound method Series.sum of 602    11.75
# 603     4.45
# Name: item_price, dtype: float64>$
# orden 249, total:<bound method Series.sum of 604    8.75
# 605    4.45
# Name: item_price, dtype: float64>$
# orden 250, total:<bound method Series.sum of 606    11.89
# 607     9.39
# Name: item_price, dtype: float64>$
# orden 251, total:<bound method Series.sum of 608    8.75
# 609    2.95
# 610    1.25
# Name: item_price, dtype: float64>$
# orden 252, total:<bound method Series.sum of 611    9.25
# 612    8.75
# Name: item_price, dtype: float64>$
# orden 253, total:<bound method Series.sum of 613    23.78
# Name: item_price, dtype: float64>$
# orden 254, total:<bound method Series.sum of 614    8.75
# 615    9.25
# 616    2.15
# 617    2.15
# 618    1.25
# Name: item_price, dtype: float64>$
# orden 255, total:<bound method Series.sum of 619    8.49
# 620    3.99
# Name: item_price, dtype: float64>$
# orden 256, total:<bound method Series.sum of 621    10.98
# 622     1.09
# Name: item_price, dtype: float64>$
# orden 257, total:<bound method Series.sum of 623    8.75
# 624    4.45
# Name: item_price, dtype: float64>$
# orden 258, total:<bound method Series.sum of 625     8.75
# 626    11.75
# 627     2.95
# 628     4.45
# Name: item_price, dtype: float64>$
# orden 259, total:<bound method Series.sum of 629    9.25
# 630    8.75
# Name: item_price, dtype: float64>$
# orden 260, total:<bound method Series.sum of 631    8.49
# 632    3.99
# Name: item_price, dtype: float64>$
# orden 261, total:<bound method Series.sum of 633    22.5
# Name: item_price, dtype: float64>$
# orden 262, total:<bound method Series.sum of 634    11.25
# 635     1.25
# Name: item_price, dtype: float64>$
# orden 263, total:<bound method Series.sum of 636    8.75
# 637    8.75
# Name: item_price, dtype: float64>$
# orden 264, total:<bound method Series.sum of 638    18.50
# 639     6.49
# Name: item_price, dtype: float64>$
# orden 265, total:<bound method Series.sum of 640    8.75
# 641    8.75
# 642    4.45
# Name: item_price, dtype: float64>$
# orden 266, total:<bound method Series.sum of 643    8.49
# 644    3.99
# Name: item_price, dtype: float64>$
# orden 267, total:<bound method Series.sum of 645    8.99
# 646    1.09
# Name: item_price, dtype: float64>$
# orden 268, total:<bound method Series.sum of 647    8.49
# 648    2.39
# Name: item_price, dtype: float64>$
# orden 269, total:<bound method Series.sum of 649    11.48
# 650     1.69
# Name: item_price, dtype: float64>$
# orden 270, total:<bound method Series.sum of 651    2.50
# 652    9.25
# 653    1.50
# Name: item_price, dtype: float64>$
# orden 271, total:<bound method Series.sum of 654    17.50
# 655     2.95
# Name: item_price, dtype: float64>$
# orden 272, total:<bound method Series.sum of 656    8.75
# 657    4.45
# Name: item_price, dtype: float64>$
# orden 273, total:<bound method Series.sum of 658    11.75
# 659     8.75
# Name: item_price, dtype: float64>$
# orden 274, total:<bound method Series.sum of 660    8.49
# 661    1.69
# Name: item_price, dtype: float64>$
# orden 275, total:<bound method Series.sum of 662    8.49
# 663    3.99
# Name: item_price, dtype: float64>$
# orden 276, total:<bound method Series.sum of 664    8.99
# 665    8.99
# 666    3.99
# 667    8.99
# Name: item_price, dtype: float64>$
# orden 277, total:<bound method Series.sum of 668    11.25
# 669     4.45
# 670     1.25
# Name: item_price, dtype: float64>$
# orden 278, total:<bound method Series.sum of 671     3.99
# 672    10.98
# Name: item_price, dtype: float64>$
# orden 279, total:<bound method Series.sum of 673    7.4
# 674    3.0
# 675    7.4
# 676    4.0
# Name: item_price, dtype: float64>$
# orden 280, total:<bound method Series.sum of 677    8.49
# 678    3.99
# Name: item_price, dtype: float64>$
# orden 281, total:<bound method Series.sum of 679    9.25
# 680    4.45
# Name: item_price, dtype: float64>$
# orden 282, total:<bound method Series.sum of 681    11.25
# 682     1.25
# 683    11.75
# 684     1.25
# Name: item_price, dtype: float64>$
# orden 283, total:<bound method Series.sum of 685    11.25
# 686     2.15
# Name: item_price, dtype: float64>$
# orden 284, total:<bound method Series.sum of 687    11.25
# 688     4.45
# 689     3.75
# 690    11.75
# Name: item_price, dtype: float64>$
# orden 285, total:<bound method Series.sum of 691    8.99
# 692    2.39
# Name: item_price, dtype: float64>$
# orden 286, total:<bound method Series.sum of 693    8.75
# 694    4.45
# 695    1.25
# Name: item_price, dtype: float64>$
# orden 287, total:<bound method Series.sum of 696    8.99
# 697    8.49
# 698    2.18
# Name: item_price, dtype: float64>$
# orden 288, total:<bound method Series.sum of 699    8.49
# 700    2.18
# 701    1.09
# Name: item_price, dtype: float64>$
# orden 289, total:<bound method Series.sum of 702    8.75
# 703    2.95
# 704    1.25
# Name: item_price, dtype: float64>$
# orden 290, total:<bound method Series.sum of 705     1.50
# 706    11.25
# Name: item_price, dtype: float64>$
# orden 291, total:<bound method Series.sum of 707    9.25
# 708    2.95
# 709    1.25
# Name: item_price, dtype: float64>$
# orden 292, total:<bound method Series.sum of 710    8.49
# 711    3.99
# Name: item_price, dtype: float64>$
# orden 293, total:<bound method Series.sum of 712    11.48
# Name: item_price, dtype: float64>$
# orden 294, total:<bound method Series.sum of 713    3.99
# 714    8.49
# Name: item_price, dtype: float64>$
# orden 295, total:<bound method Series.sum of 715    11.25
# 716     1.25
# Name: item_price, dtype: float64>$
# orden 296, total:<bound method Series.sum of 717    8.99
# 718    1.69
# Name: item_price, dtype: float64>$
# orden 297, total:<bound method Series.sum of 719    11.25
# 720     1.25
# Name: item_price, dtype: float64>$
# orden 298, total:<bound method Series.sum of 721    6.49
# 722    8.75
# Name: item_price, dtype: float64>$
# orden 299, total:<bound method Series.sum of 723    9.25
# 724    8.75
# 725    2.95
# Name: item_price, dtype: float64>$
# orden 300, total:<bound method Series.sum of 726     8.75
# 727    11.75
# Name: item_price, dtype: float64>$
# orden 301, total:<bound method Series.sum of 728    8.69
# 729    8.69
# 730    2.29
# Name: item_price, dtype: float64>$
# orden 302, total:<bound method Series.sum of 731    3.99
# 732    8.49
# Name: item_price, dtype: float64>$
# orden 303, total:<bound method Series.sum of 733    8.75
# 734    8.75
# Name: item_price, dtype: float64>$
# orden 304, total:<bound method Series.sum of 735     1.25
# 736    11.75
# 737    11.25
# 738    11.25
# Name: item_price, dtype: float64>$
# orden 305, total:<bound method Series.sum of 739    11.25
# 740     1.25
# 741     9.25
# Name: item_price, dtype: float64>$
# orden 306, total:<bound method Series.sum of 742    11.75
# 743     6.49
# Name: item_price, dtype: float64>$
# orden 307, total:<bound method Series.sum of 744    3.99
# 745    8.49
# Name: item_price, dtype: float64>$
# orden 308, total:<bound method Series.sum of 746    11.25
# 747     2.15
# Name: item_price, dtype: float64>$
# orden 309, total:<bound method Series.sum of 748    11.25
# 749    11.89
# Name: item_price, dtype: float64>$
# orden 310, total:<bound method Series.sum of 750    8.99
# 751    1.69
# Name: item_price, dtype: float64>$
# orden 311, total:<bound method Series.sum of 752    8.99
# 753    8.99
# 754    3.99
# 755    8.99
# Name: item_price, dtype: float64>$
# orden 312, total:<bound method Series.sum of 756    9.25
# 757    9.25
# 758    2.15
# Name: item_price, dtype: float64>$
# orden 313, total:<bound method Series.sum of 759    7.4
# 760    7.4
# Name: item_price, dtype: float64>$
# orden 314, total:<bound method Series.sum of 761    8.75
# 762    8.75
# Name: item_price, dtype: float64>$
# orden 315, total:<bound method Series.sum of 763    9.25
# 764    4.45
# Name: item_price, dtype: float64>$
# orden 316, total:<bound method Series.sum of 765    11.25
# 766     1.25
# Name: item_price, dtype: float64>$
# orden 317, total:<bound method Series.sum of 767    11.75
# 768    11.25
# 769     1.25
# Name: item_price, dtype: float64>$
# orden 318, total:<bound method Series.sum of 770    3.99
# 771    8.49
# Name: item_price, dtype: float64>$
# orden 319, total:<bound method Series.sum of 772    8.49
# 773    8.49
# 774    8.99
# Name: item_price, dtype: float64>$
# orden 320, total:<bound method Series.sum of 775    8.75
# 776    2.15
# 777    1.25
# Name: item_price, dtype: float64>$
# orden 321, total:<bound method Series.sum of 778    8.49
# 779    1.09
# 780    1.09
# Name: item_price, dtype: float64>$
# orden 322, total:<bound method Series.sum of 781    8.75
# 782    2.95
# 783    1.25
# Name: item_price, dtype: float64>$
# orden 323, total:<bound method Series.sum of 784    9.25
# 785    1.25
# 786    2.15
# Name: item_price, dtype: float64>$
# orden 324, total:<bound method Series.sum of 787    11.25
# 788     1.25
# Name: item_price, dtype: float64>$
# orden 325, total:<bound method Series.sum of 789    4.45
# 790    8.75
# 791    2.50
# Name: item_price, dtype: float64>$
# orden 326, total:<bound method Series.sum of 792    8.90
# 793    8.75
# 794    8.75
# 795    8.75
# Name: item_price, dtype: float64>$
# orden 327, total:<bound method Series.sum of 796    11.25
# 797    11.25
# Name: item_price, dtype: float64>$
# orden 328, total:<bound method Series.sum of 798    10.98
# 799     3.99
# Name: item_price, dtype: float64>$
# orden 329, total:<bound method Series.sum of 800    10.98
# 801     3.99
# Name: item_price, dtype: float64>$
# orden 330, total:<bound method Series.sum of 802    1.69
# 803    8.99
# Name: item_price, dtype: float64>$
# orden 331, total:<bound method Series.sum of 804    9.25
# 805    8.75
# Name: item_price, dtype: float64>$
# orden 332, total:<bound method Series.sum of 806    8.99
# 807    1.09
# Name: item_price, dtype: float64>$
# orden 333, total:<bound method Series.sum of 808    9.25
# 809    2.95
# Name: item_price, dtype: float64>$
# orden 334, total:<bound method Series.sum of 810    8.75
# 811    9.25
# Name: item_price, dtype: float64>$
# orden 335, total:<bound method Series.sum of 812    3.99
# 813    8.49
# Name: item_price, dtype: float64>$
# orden 336, total:<bound method Series.sum of 814    8.75
# 815    8.75
# Name: item_price, dtype: float64>$
# orden 337, total:<bound method Series.sum of 816    22.5
# Name: item_price, dtype: float64>$
# orden 338, total:<bound method Series.sum of 817    10.98
# 818     3.27
# 819     3.99
# 820     8.99
# 821     1.09
# Name: item_price, dtype: float64>$
# orden 339, total:<bound method Series.sum of 822    11.08
# Name: item_price, dtype: float64>$
# orden 340, total:<bound method Series.sum of 823    8.75
# 824    4.45
# Name: item_price, dtype: float64>$
# orden 341, total:<bound method Series.sum of 825    11.08
# Name: item_price, dtype: float64>$
# orden 342, total:<bound method Series.sum of 826    3.99
# 827    8.49
# Name: item_price, dtype: float64>$
# orden 343, total:<bound method Series.sum of 828     4.30
# 829     9.25
# 830     8.75
# 831    11.25
# 832    11.25
# 833     9.25
# Name: item_price, dtype: float64>$
# orden 344, total:<bound method Series.sum of 834    8.49
# 835    8.99
# 836    8.49
# Name: item_price, dtype: float64>$
# orden 345, total:<bound method Series.sum of 837    8.75
# 838    2.95
# 839    4.45
# Name: item_price, dtype: float64>$
# orden 346, total:<bound method Series.sum of 840    9.25
# 841    2.95
# 842    9.25
# 843    8.75
# Name: item_price, dtype: float64>$
# orden 347, total:<bound method Series.sum of 844    11.25
# 845     4.45
# Name: item_price, dtype: float64>$
# orden 348, total:<bound method Series.sum of 846    16.98
# Name: item_price, dtype: float64>$
# orden 349, total:<bound method Series.sum of 847    8.49
# 848    2.39
# Name: item_price, dtype: float64>$
# orden 350, total:<bound method Series.sum of 849    11.25
# 850     3.75
# Name: item_price, dtype: float64>$
# orden 351, total:<bound method Series.sum of 851    9.25
# 852    4.45
# Name: item_price, dtype: float64>$
# orden 352, total:<bound method Series.sum of 853    9.25
# 854    9.25
# 855    4.45
# Name: item_price, dtype: float64>$
# orden 353, total:<bound method Series.sum of 856    8.75
# 857    9.25
# Name: item_price, dtype: float64>$
# orden 354, total:<bound method Series.sum of 858    8.75
# 859    9.25
# Name: item_price, dtype: float64>$
# orden 355, total:<bound method Series.sum of 860    9.25
# 861    9.25
# Name: item_price, dtype: float64>$
# orden 356, total:<bound method Series.sum of 862    11.48
# 863     8.99
# Name: item_price, dtype: float64>$
# orden 357, total:<bound method Series.sum of 864    22.5
# Name: item_price, dtype: float64>$
# orden 358, total:<bound method Series.sum of 865    11.75
# 866    11.25
# 867     1.25
# Name: item_price, dtype: float64>$
# orden 359, total:<bound method Series.sum of 868    8.75
# 869    2.15
# 870    1.25
# Name: item_price, dtype: float64>$
# orden 360, total:<bound method Series.sum of 871    11.25
# 872     8.75
# 873     1.25
# Name: item_price, dtype: float64>$
# orden 361, total:<bound method Series.sum of 874    11.25
# 875     1.50
# Name: item_price, dtype: float64>$
# orden 362, total:<bound method Series.sum of 876    11.25
# 877    11.25
# Name: item_price, dtype: float64>$
# orden 363, total:<bound method Series.sum of 878    9.25
# 879    6.49
# 880    8.90
# Name: item_price, dtype: float64>$
# orden 364, total:<bound method Series.sum of 881    8.75
# 882    4.45
# Name: item_price, dtype: float64>$
# orden 365, total:<bound method Series.sum of 883    11.25
# 884     1.25
# Name: item_price, dtype: float64>$
# orden 366, total:<bound method Series.sum of 885    17.50
# 886     9.25
# Name: item_price, dtype: float64>$
# orden 367, total:<bound method Series.sum of 887     8.75
# 888    11.75
# 889     3.00
# Name: item_price, dtype: float64>$
# orden 368, total:<bound method Series.sum of 890    8.49
# 891    8.49
# Name: item_price, dtype: float64>$
# orden 369, total:<bound method Series.sum of 892    10.98
# 893     8.99
# 894     3.99
# Name: item_price, dtype: float64>$
# orden 370, total:<bound method Series.sum of 895    8.75
# 896    4.45
# Name: item_price, dtype: float64>$
# orden 371, total:<bound method Series.sum of 897    8.99
# 898    1.69
# Name: item_price, dtype: float64>$
# orden 372, total:<bound method Series.sum of 899    11.75
# 900     8.75
# Name: item_price, dtype: float64>$
# orden 373, total:<bound method Series.sum of 901    11.25
# 902     4.45
# Name: item_price, dtype: float64>$
# orden 374, total:<bound method Series.sum of 903    11.75
# 904     1.25
# Name: item_price, dtype: float64>$
# orden 375, total:<bound method Series.sum of 905    11.75
# 906     2.95
# Name: item_price, dtype: float64>$
# orden 376, total:<bound method Series.sum of 907    8.99
# 908    8.99
# 909    2.18
# Name: item_price, dtype: float64>$
# orden 377, total:<bound method Series.sum of 910    17.98
# 911     8.99
# Name: item_price, dtype: float64>$
# orden 378, total:<bound method Series.sum of 912    8.49
# 913    1.69
# Name: item_price, dtype: float64>$
# orden 379, total:<bound method Series.sum of 914    11.75
# 915    11.25
# 916     2.95
# 917     3.75
# 918     9.25
# Name: item_price, dtype: float64>$
# orden 380, total:<bound method Series.sum of 919    11.75
# 920     8.75
# 921     2.15
# 922     1.50
# Name: item_price, dtype: float64>$
# orden 381, total:<bound method Series.sum of 923    8.49
# 924    8.49
# 925    3.39
# Name: item_price, dtype: float64>$
# orden 382, total:<bound method Series.sum of 926    8.69
# 927    3.89
# Name: item_price, dtype: float64>$
# orden 383, total:<bound method Series.sum of 928    8.75
# 929    4.45
# Name: item_price, dtype: float64>$
# orden 384, total:<bound method Series.sum of 930     8.75
# 931    11.25
# 932     2.15
# 933     8.75
# Name: item_price, dtype: float64>$
# orden 385, total:<bound method Series.sum of 934    8.49
# 935    1.69
# Name: item_price, dtype: float64>$
# orden 386, total:<bound method Series.sum of 936    8.49
# 937    8.49
# Name: item_price, dtype: float64>$
# orden 387, total:<bound method Series.sum of 938     1.25
# 939     8.75
# 940    11.75
# 941    11.75
# Name: item_price, dtype: float64>$
# orden 388, total:<bound method Series.sum of 942    8.99
# 943    1.09
# Name: item_price, dtype: float64>$
# orden 389, total:<bound method Series.sum of 944    8.75
# 945    4.45
# 946    8.75
# 947    2.95
# 948    8.75
# 949    2.15
# Name: item_price, dtype: float64>$
# orden 390, total:<bound method Series.sum of 950    3.99
# 951    8.49
# Name: item_price, dtype: float64>$
# orden 391, total:<bound method Series.sum of 952    8.99
# 953    3.99
# Name: item_price, dtype: float64>$
# orden 392, total:<bound method Series.sum of 954    8.49
# 955    1.69
# 956    1.09
# Name: item_price, dtype: float64>$
# orden 393, total:<bound method Series.sum of 957    8.99
# 958    1.09
# Name: item_price, dtype: float64>$
# orden 394, total:<bound method Series.sum of 959    9.25
# 960    8.75
# Name: item_price, dtype: float64>$
# orden 395, total:<bound method Series.sum of 961    8.99
# 962    2.39
# Name: item_price, dtype: float64>$
# orden 396, total:<bound method Series.sum of 963     1.25
# 964     1.25
# 965    11.25
# 966    11.25
# Name: item_price, dtype: float64>$
# orden 397, total:<bound method Series.sum of 967    9.25
# 968    9.25
# Name: item_price, dtype: float64>$
# orden 398, total:<bound method Series.sum of 969    11.25
# 970     1.50
# Name: item_price, dtype: float64>$
# orden 399, total:<bound method Series.sum of 971    3.99
# 972    8.49
# Name: item_price, dtype: float64>$
# orden 400, total:<bound method Series.sum of 973    11.25
# 974     9.25
# 975    11.25
# Name: item_price, dtype: float64>$
# orden 401, total:<bound method Series.sum of 976    17.5
# Name: item_price, dtype: float64>$
# orden 402, total:<bound method Series.sum of 977    8.75
# 978    8.90
# 979    8.75
# 980    8.75
# Name: item_price, dtype: float64>$
# orden 403, total:<bound method Series.sum of 981    8.99
# 982    2.39
# Name: item_price, dtype: float64>$
# orden 404, total:<bound method Series.sum of 983    11.25
# 984     9.25
# 985     2.15
# Name: item_price, dtype: float64>$
# orden 405, total:<bound method Series.sum of 986    11.25
# 987     1.25
# Name: item_price, dtype: float64>$
# orden 406, total:<bound method Series.sum of 988    11.75
# 989     1.25
# Name: item_price, dtype: float64>$
# orden 407, total:<bound method Series.sum of 990    11.25
# 991    11.75
# Name: item_price, dtype: float64>$
# orden 408, total:<bound method Series.sum of 992     1.25
# 993    11.25
# 994    11.25
# Name: item_price, dtype: float64>$
# orden 409, total:<bound method Series.sum of 995     8.49
# 996    10.98
# Name: item_price, dtype: float64>$
# orden 410, total:<bound method Series.sum of 997    8.75
# 998    1.25
# 999    8.75
# Name: item_price, dtype: float64>$
# orden 411, total:<bound method Series.sum of 1000    8.49
# 1001    8.49
# Name: item_price, dtype: float64>$
# orden 412, total:<bound method Series.sum of 1002    1.50
# 1003    1.50
# 1004    8.75
# 1005    4.45
# Name: item_price, dtype: float64>$
# orden 413, total:<bound method Series.sum of 1006    11.25
# 1007     1.25
# 1008    11.75
# Name: item_price, dtype: float64>$
# orden 414, total:<bound method Series.sum of 1009    8.49
# 1010    2.39
# Name: item_price, dtype: float64>$
# orden 415, total:<bound method Series.sum of 1011    9.25
# 1012    4.45
# Name: item_price, dtype: float64>$
# orden 416, total:<bound method Series.sum of 1013    9.25
# 1014    8.75
# Name: item_price, dtype: float64>$
# orden 417, total:<bound method Series.sum of 1015    8.99
# 1016    1.69
# Name: item_price, dtype: float64>$
# orden 418, total:<bound method Series.sum of 1017    17.5
# Name: item_price, dtype: float64>$
# orden 419, total:<bound method Series.sum of 1018    2.39
# 1019    8.99
# 1020    8.99
# Name: item_price, dtype: float64>$
# orden 420, total:<bound method Series.sum of 1021    11.25
# 1022     4.45
# Name: item_price, dtype: float64>$
# orden 421, total:<bound method Series.sum of 1023    8.75
# 1024    4.45
# Name: item_price, dtype: float64>$
# orden 422, total:<bound method Series.sum of 1025    9.25
# 1026    6.49
# Name: item_price, dtype: float64>$
# orden 423, total:<bound method Series.sum of 1027    10.98
# 1028     8.49
# Name: item_price, dtype: float64>$
# orden 424, total:<bound method Series.sum of 1029    8.49
# 1030    1.09
# 1031    1.69
# Name: item_price, dtype: float64>$
# orden 425, total:<bound method Series.sum of 1032    9.25
# 1033    4.45
# Name: item_price, dtype: float64>$
# orden 426, total:<bound method Series.sum of 1034    8.75
# 1035    1.25
# 1036    2.95
# Name: item_price, dtype: float64>$
# orden 427, total:<bound method Series.sum of 1037    3.99
# 1038    8.49
# Name: item_price, dtype: float64>$
# orden 428, total:<bound method Series.sum of 1039    11.75
# 1040    11.75
# 1041     2.15
# Name: item_price, dtype: float64>$
# orden 429, total:<bound method Series.sum of 1042    11.48
# Name: item_price, dtype: float64>$
# orden 430, total:<bound method Series.sum of 1043    8.75
# 1044    2.15
# 1045    1.25
# Name: item_price, dtype: float64>$
# orden 431, total:<bound method Series.sum of 1046    11.25
# 1047     2.15
# 1048     1.25
# Name: item_price, dtype: float64>$
# orden 432, total:<bound method Series.sum of 1049    8.75
# 1050    8.75
# 1051    6.49
# Name: item_price, dtype: float64>$
# orden 433, total:<bound method Series.sum of 1052    1.69
# 1053    8.99
# Name: item_price, dtype: float64>$
# orden 434, total:<bound method Series.sum of 1054     8.75
# 1055    11.75
# Name: item_price, dtype: float64>$
# orden 435, total:<bound method Series.sum of 1056    10.98
# 1057     1.09
# Name: item_price, dtype: float64>$
# orden 436, total:<bound method Series.sum of 1058    8.49
# 1059    3.39
# Name: item_price, dtype: float64>$
# orden 437, total:<bound method Series.sum of 1060    8.75
# 1061    2.15
# 1062    1.25
# ...
# 4257    2.15
# Name: item_price, dtype: float64>$
# orden 1699, total:<bound method Series.sum of 4258     8.75
# 4259    11.25
# 4260    11.25
# Name: item_price, dtype: float64>$
# orden 1700, total:<bound method Series.sum of 4261    11.25
# 4262    11.75
# Name: item_price, dtype: float64>$
# orden 1701, total:<bound method Series.sum of 4263    11.25
# 4264     2.15
# 4265    11.25
# 4266     2.15
# Name: item_price, dtype: float64>$
# orden 1702, total:<bound method Series.sum of 4267    8.99
# 4268    8.99
# Name: item_price, dtype: float64>$
# orden 1703, total:<bound method Series.sum of 4269     8.75
# 4270     9.25
# 4271     9.25
# 4272    11.25
# Name: item_price, dtype: float64>$
# orden 1704, total:<bound method Series.sum of 4273    8.75
# 4274    4.45
# Name: item_price, dtype: float64>$
# orden 1705, total:<bound method Series.sum of 4275    8.75
# 4276    1.25
# 4277    4.45
# Name: item_price, dtype: float64>$
# orden 1706, total:<bound method Series.sum of 4278    11.25
# 4279     1.25
# Name: item_price, dtype: float64>$
# orden 1707, total:<bound method Series.sum of 4280    8.75
# 4281    8.75
# Name: item_price, dtype: float64>$
# orden 1708, total:<bound method Series.sum of 4282    11.25
# 4283     8.75
# Name: item_price, dtype: float64>$
# orden 1709, total:<bound method Series.sum of 4284    1.25
# 4285    1.25
# 4286    1.25
# 4287    9.25
# Name: item_price, dtype: float64>$
# orden 1710, total:<bound method Series.sum of 4288    11.75
# 4289     2.15
# Name: item_price, dtype: float64>$
# orden 1711, total:<bound method Series.sum of 4290    8.75
# 4291    4.45
# Name: item_price, dtype: float64>$
# orden 1712, total:<bound method Series.sum of 4292    8.75
# 4293    4.45
# Name: item_price, dtype: float64>$
# orden 1713, total:<bound method Series.sum of 4294    11.25
# 4295     9.25
# Name: item_price, dtype: float64>$
# orden 1714, total:<bound method Series.sum of 4296    8.75
# 4297    9.25
# 4298    4.45
# Name: item_price, dtype: float64>$
# orden 1715, total:<bound method Series.sum of 4299    11.75
# 4300     4.45
# 4301     1.25
# Name: item_price, dtype: float64>$
# orden 1716, total:<bound method Series.sum of 4302     4.45
# 4303    11.75
# Name: item_price, dtype: float64>$
# orden 1717, total:<bound method Series.sum of 4304     9.25
# 4305    11.25
# 4306     2.15
# Name: item_price, dtype: float64>$
# orden 1718, total:<bound method Series.sum of 4307    23.50
# 4308     9.25
# 4309     2.15
# Name: item_price, dtype: float64>$
# orden 1719, total:<bound method Series.sum of 4310    18.50
# 4311     8.75
# 4312     5.90
# Name: item_price, dtype: float64>$
# orden 1720, total:<bound method Series.sum of 4313    11.89
# 4314     4.45
# Name: item_price, dtype: float64>$
# orden 1721, total:<bound method Series.sum of 4315    8.75
# 4316    4.45
# Name: item_price, dtype: float64>$
# orden 1722, total:<bound method Series.sum of 4317    9.25
# 4318    2.95
# Name: item_price, dtype: float64>$
# orden 1723, total:<bound method Series.sum of 4319    11.25
# 4320     2.95
# Name: item_price, dtype: float64>$
# orden 1724, total:<bound method Series.sum of 4321    11.25
# 4322    11.25
# Name: item_price, dtype: float64>$
# orden 1725, total:<bound method Series.sum of 4323    11.25
# 4324     2.95
# Name: item_price, dtype: float64>$
# orden 1726, total:<bound method Series.sum of 4325    11.75
# 4326     9.25
# Name: item_price, dtype: float64>$
# orden 1727, total:<bound method Series.sum of 4327    9.25
# 4328    2.95
# Name: item_price, dtype: float64>$
# orden 1728, total:<bound method Series.sum of 4329    11.25
# 4330     2.15
# Name: item_price, dtype: float64>$
# orden 1729, total:<bound method Series.sum of 4331    9.25
# 4332    8.90
# Name: item_price, dtype: float64>$
# orden 1730, total:<bound method Series.sum of 4333     8.75
# 4334    11.25
# Name: item_price, dtype: float64>$
# orden 1731, total:<bound method Series.sum of 4335    11.25
# 4336    11.25
# Name: item_price, dtype: float64>$
# orden 1732, total:<bound method Series.sum of 4337    8.75
# 4338    2.15
# 4339    1.25
# Name: item_price, dtype: float64>$
# orden 1733, total:<bound method Series.sum of 4340    11.25
# 4341     1.25
# Name: item_price, dtype: float64>$
# orden 1734, total:<bound method Series.sum of 4342    8.75
# 4343    4.45
# Name: item_price, dtype: float64>$
# orden 1735, total:<bound method Series.sum of 4344     1.25
# 4345    11.25
# 4346    11.25
# Name: item_price, dtype: float64>$
# orden 1736, total:<bound method Series.sum of 4347    11.75
# 4348     1.25
# Name: item_price, dtype: float64>$
# orden 1737, total:<bound method Series.sum of 4349    11.25
# 4350    11.25
# 4351    11.25
# Name: item_price, dtype: float64>$
# orden 1738, total:<bound method Series.sum of 4352     8.75
# 4353     8.75
# 4354    18.50
# Name: item_price, dtype: float64>$
# orden 1739, total:<bound method Series.sum of 4355    11.75
# 4356     1.25
# Name: item_price, dtype: float64>$
# orden 1740, total:<bound method Series.sum of 4357    4.45
# 4358    9.25
# Name: item_price, dtype: float64>$
# orden 1741, total:<bound method Series.sum of 4359    6.49
# 4360    4.45
# 4361    8.75
# Name: item_price, dtype: float64>$
# orden 1742, total:<bound method Series.sum of 4362    11.25
# 4363     6.49
# 4364    11.75
# Name: item_price, dtype: float64>$
# orden 1743, total:<bound method Series.sum of 4365    8.75
# 4366    9.25
# Name: item_price, dtype: float64>$
# orden 1744, total:<bound method Series.sum of 4367    11.25
# 4368     2.15
# Name: item_price, dtype: float64>$
# orden 1745, total:<bound method Series.sum of 4369     8.75
# 4370     4.45
# 4371    11.25
# 4372     4.45
# Name: item_price, dtype: float64>$
# orden 1746, total:<bound method Series.sum of 4373    8.75
# 4374    9.25
# 4375    4.45
# 4376    1.25
# 4377    1.25
# Name: item_price, dtype: float64>$
# orden 1747, total:<bound method Series.sum of 4378     8.75
# 4379    11.25
# Name: item_price, dtype: float64>$
# orden 1748, total:<bound method Series.sum of 4380    11.75
# 4381     2.15
# 4382    11.75
# Name: item_price, dtype: float64>$
# orden 1749, total:<bound method Series.sum of 4383     4.45
# 4384    11.75
# 4385     1.25
# Name: item_price, dtype: float64>$
# orden 1750, total:<bound method Series.sum of 4386    11.75
# 4387    11.75
# Name: item_price, dtype: float64>$
# orden 1751, total:<bound method Series.sum of 4388    11.25
# 4389     4.30
# 4390     9.39
# Name: item_price, dtype: float64>$
# orden 1752, total:<bound method Series.sum of 4391    9.39
# 4392    8.75
# Name: item_price, dtype: float64>$
# orden 1753, total:<bound method Series.sum of 4393    1.25
# 4394    9.25
# 4395    4.45
# Name: item_price, dtype: float64>$
# orden 1754, total:<bound method Series.sum of 4396    11.25
# 4397     1.25
# Name: item_price, dtype: float64>$
# orden 1755, total:<bound method Series.sum of 4398    8.75
# 4399    1.25
# 4400    2.95
# Name: item_price, dtype: float64>$
# orden 1756, total:<bound method Series.sum of 4401    11.25
# 4402     4.45
# Name: item_price, dtype: float64>$
# orden 1757, total:<bound method Series.sum of 4403    8.75
# 4404    1.50
# 4405    4.45
# Name: item_price, dtype: float64>$
# orden 1758, total:<bound method Series.sum of 4406    4.45
# 4407    9.25
# Name: item_price, dtype: float64>$
# orden 1759, total:<bound method Series.sum of 4408    8.75
# 4409    2.95
# 4410    1.25
# Name: item_price, dtype: float64>$
# orden 1760, total:<bound method Series.sum of 4411    11.25
# 4412     2.95
# Name: item_price, dtype: float64>$
# orden 1761, total:<bound method Series.sum of 4413    8.75
# 4414    8.75
# 4415    8.75
# 4416    8.75
# 4417    4.30
# Name: item_price, dtype: float64>$
# orden 1762, total:<bound method Series.sum of 4418    9.25
# 4419    9.39
# Name: item_price, dtype: float64>$
# orden 1763, total:<bound method Series.sum of 4420    4.45
# 4421    9.25
# 4422    1.25
# Name: item_price, dtype: float64>$
# orden 1764, total:<bound method Series.sum of 4423    22.50
# 4424     4.45
# 4425     2.95
# 4426     2.15
# 4427    23.50
# Name: item_price, dtype: float64>$
# orden 1765, total:<bound method Series.sum of 4428    11.75
# 4429     2.15
# 4430     1.25
# Name: item_price, dtype: float64>$
# orden 1766, total:<bound method Series.sum of 4431     9.25
# 4432     4.45
# 4433    11.25
# 4434    11.75
# Name: item_price, dtype: float64>$
# orden 1767, total:<bound method Series.sum of 4435    17.5
# Name: item_price, dtype: float64>$
# orden 1768, total:<bound method Series.sum of 4436     8.75
# 4437    11.75
# 4438    11.25
# Name: item_price, dtype: float64>$
# orden 1769, total:<bound method Series.sum of 4439    8.75
# 4440    4.45
# Name: item_price, dtype: float64>$
# orden 1770, total:<bound method Series.sum of 4441    11.75
# 4442     1.50
# Name: item_price, dtype: float64>$
# orden 1771, total:<bound method Series.sum of 4443    8.75
# 4444    8.75
# Name: item_price, dtype: float64>$
# orden 1772, total:<bound method Series.sum of 4445    11.75
# 4446     9.25
# 4447    11.25
# Name: item_price, dtype: float64>$
# orden 1773, total:<bound method Series.sum of 4448     4.45
# 4449    11.75
# Name: item_price, dtype: float64>$
# orden 1774, total:<bound method Series.sum of 4450    9.25
# 4451    4.45
# Name: item_price, dtype: float64>$
# orden 1775, total:<bound method Series.sum of 4452    11.25
# 4453     8.75
# 4454     8.75
# Name: item_price, dtype: float64>$
# orden 1776, total:<bound method Series.sum of 4455    2.15
# 4456    1.50
# 4457    8.75
# Name: item_price, dtype: float64>$
# orden 1777, total:<bound method Series.sum of 4458    4.45
# 4459    9.25
# Name: item_price, dtype: float64>$
# orden 1778, total:<bound method Series.sum of 4460    8.75
# 4461    1.50
# 4462    1.25
# 4463    1.25
# Name: item_price, dtype: float64>$
# orden 1779, total:<bound method Series.sum of 4464    1.25
# 4465    8.75
# 4466    2.95
# Name: item_price, dtype: float64>$
# orden 1780, total:<bound method Series.sum of 4467    11.25
# 4468    11.25
# Name: item_price, dtype: float64>$
# orden 1781, total:<bound method Series.sum of 4469     1.50
# 4470    11.75
# Name: item_price, dtype: float64>$
# orden 1782, total:<bound method Series.sum of 4471    11.25
# 4472     2.15
# Name: item_price, dtype: float64>$
# orden 1783, total:<bound method Series.sum of 4473    9.25
# 4474    8.75
# Name: item_price, dtype: float64>$
# orden 1784, total:<bound method Series.sum of 4475    11.75
# 4476     2.95
# Name: item_price, dtype: float64>$
# orden 1785, total:<bound method Series.sum of 4477    1.50
# 4478    8.75
# 4479    1.50
# 4480    1.25
# Name: item_price, dtype: float64>$
# orden 1786, total:<bound method Series.sum of 4481     8.75
# 4482    11.75
# 4483    11.25
# 4484    11.25
# 4485    11.75
# 4486    11.25
# 4487    11.75
# 4488     8.75
# 4489    17.80
# 4490     5.00
# 4491     5.00
# Name: item_price, dtype: float64>$
# orden 1787, total:<bound method Series.sum of 4492    8.75
# 4493    2.95
# 4494    1.25
# Name: item_price, dtype: float64>$
# orden 1788, total:<bound method Series.sum of 4495    11.25
# 4496     1.25
# 4497     2.15
# Name: item_price, dtype: float64>$
# orden 1789, total:<bound method Series.sum of 4498    11.25
# 4499     2.50
# 4500     9.25
# Name: item_price, dtype: float64>$
# orden 1790, total:<bound method Series.sum of 4501     1.25
# 4502    11.25
# 4503     2.95
# Name: item_price, dtype: float64>$
# orden 1791, total:<bound method Series.sum of 4504    11.75
# 4505     2.15
# Name: item_price, dtype: float64>$
# orden 1792, total:<bound method Series.sum of 4506    11.25
# 4507     1.50
# Name: item_price, dtype: float64>$
# orden 1793, total:<bound method Series.sum of 4508     8.99
# 4509     1.99
# 4510    11.49
# Name: item_price, dtype: float64>$
# orden 1794, total:<bound method Series.sum of 4511    8.75
# 4512    4.45
# 4513    1.25
# Name: item_price, dtype: float64>$
# orden 1795, total:<bound method Series.sum of 4514    8.75
# 4515    4.45
# 4516    1.25
# Name: item_price, dtype: float64>$
# orden 1796, total:<bound method Series.sum of 4517     1.50
# 4518    11.75
# Name: item_price, dtype: float64>$
# orden 1797, total:<bound method Series.sum of 4519    8.75
# 4520    8.75
# Name: item_price, dtype: float64>$
# orden 1798, total:<bound method Series.sum of 4521    11.25
# 4522     6.49
# 4523    11.75
# Name: item_price, dtype: float64>$
# orden 1799, total:<bound method Series.sum of 4524    8.75
# 4525    2.15
# 4526    1.25
# Name: item_price, dtype: float64>$
# orden 1800, total:<bound method Series.sum of 4527    6.49
# 4528    8.75
# 4529    4.45
# Name: item_price, dtype: float64>$
# orden 1801, total:<bound method Series.sum of 4530    8.75
# 4531    4.45
# Name: item_price, dtype: float64>$
# orden 1802, total:<bound method Series.sum of 4532     8.75
# 4533    11.25
# Name: item_price, dtype: float64>$
# orden 1803, total:<bound method Series.sum of 4534    4.45
# 4535    6.49
# 4536    9.25
# Name: item_price, dtype: float64>$
# orden 1804, total:<bound method Series.sum of 4537    8.75
# 4538    1.25
# 4539    4.45
# Name: item_price, dtype: float64>$
# orden 1805, total:<bound method Series.sum of 4540    11.25
# 4541     8.75
# Name: item_price, dtype: float64>$
# orden 1806, total:<bound method Series.sum of 4542    1.50
# 4543    8.75
# 4544    1.50
# 4545    1.25
# Name: item_price, dtype: float64>$
# orden 1807, total:<bound method Series.sum of 4546    9.25
# 4547    9.39
# Name: item_price, dtype: float64>$
# orden 1808, total:<bound method Series.sum of 4548    4.45
# 4549    9.25
# Name: item_price, dtype: float64>$
# orden 1809, total:<bound method Series.sum of 4550    8.75
# 4551    4.45
# 4552    1.25
# Name: item_price, dtype: float64>$
# orden 1810, total:<bound method Series.sum of 4553    11.25
# 4554    11.75
# Name: item_price, dtype: float64>$
# orden 1811, total:<bound method Series.sum of 4555     8.75
# 4556    11.25
# 4557     9.25
# Name: item_price, dtype: float64>$
# orden 1812, total:<bound method Series.sum of 4558     8.75
# 4559    11.25
# 4560     2.50
# Name: item_price, dtype: float64>$
# orden 1813, total:<bound method Series.sum of 4561    17.5
# Name: item_price, dtype: float64>$
# orden 1814, total:<bound method Series.sum of 4562    9.25
# 4563    4.45
# Name: item_price, dtype: float64>$
# orden 1815, total:<bound method Series.sum of 4564    11.25
# 4565     1.25
# Name: item_price, dtype: float64>$
# orden 1816, total:<bound method Series.sum of 4566    8.75
# 4567    4.45
# Name: item_price, dtype: float64>$
# orden 1817, total:<bound method Series.sum of 4568    1.50
# 4569    8.75
# 4570    1.50
# 4571    1.25
# Name: item_price, dtype: float64>$
# orden 1818, total:<bound method Series.sum of 4572    9.39
# 4573    8.75
# Name: item_price, dtype: float64>$
# orden 1819, total:<bound method Series.sum of 4574    8.75
# 4575    4.45
# Name: item_price, dtype: float64>$
# orden 1820, total:<bound method Series.sum of 4576    11.25
# 4577     1.25
# Name: item_price, dtype: float64>$
# orden 1821, total:<bound method Series.sum of 4578    9.25
# 4579    4.45
# Name: item_price, dtype: float64>$
# orden 1822, total:<bound method Series.sum of 4580    11.25
# 4581     8.75
# 4582     3.00
# Name: item_price, dtype: float64>$
# orden 1823, total:<bound method Series.sum of 4583    8.75
# 4584    2.15
# 4585    1.25
# Name: item_price, dtype: float64>$
# orden 1824, total:<bound method Series.sum of 4586    11.25
# 4587    11.25
# 4588     4.45
# Name: item_price, dtype: float64>$
# orden 1825, total:<bound method Series.sum of 4589    11.25
# 4590    11.25
# 4591     8.75
# 4592    11.75
# 4593    11.75
# 4594    11.75
# Name: item_price, dtype: float64>$
# orden 1826, total:<bound method Series.sum of 4595    8.75
# 4596    4.45
# 4597    1.25
# 4598    1.50
# Name: item_price, dtype: float64>$
# orden 1827, total:<bound method Series.sum of 4599    8.75
# 4600    4.45
# 4601    1.25
# 4602    9.25
# 4603    9.25
# Name: item_price, dtype: float64>$
# orden 1828, total:<bound method Series.sum of 4604    8.75
# 4605    4.45
# 4606    1.25
# Name: item_price, dtype: float64>$
# orden 1829, total:<bound method Series.sum of 4607    11.75
# 4608    11.25
# 4609     1.25
# Name: item_price, dtype: float64>$
# orden 1830, total:<bound method Series.sum of 4610    11.75
# 4611    11.25
# Name: item_price, dtype: float64>$
# orden 1831, total:<bound method Series.sum of 4612    9.25
# 4613    2.15
# 4614    1.50
# Name: item_price, dtype: float64>$
# orden 1832, total:<bound method Series.sum of 4615    8.75
# 4616    4.45
# Name: item_price, dtype: float64>$
# orden 1833, total:<bound method Series.sum of 4617    11.75
# 4618    11.75
# Name: item_price, dtype: float64>$
# orden 1834, total:<bound method Series.sum of 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, dtype: float64>$

# %%
chipo.groupby("order_id")["item_price"].sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
orders_mas_de_10 = chipo.groupby("order_id")["item_price"].sum() > 10

# %%
<  >

# %% [markdown]
# ### Step 4.3: Y en cuántos pedidos se ha pagado más de 10$ por un mismo producto? Es lo mismo?

# %%
chipo[chipo["item_price"]>10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...                                                 ...         ...
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...       11.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
#
#       unit_price
# 4           8.49
# 5          10.98
# 7          11.75
# 13         11.25
# 23         10.98
# ...          ...
# 4610       11.75
# 4611       11.25
# 4617       11.75
# 4618       11.75
# 4619       11.25
#
# [1130 rows x 6 columns]

# %%
chipo[chipo["item_price"]>10]["order_id"].nunique()
# Out:
# 863

# %% [markdown]
# ### Step 5. What is the price of each item and name it unit_price. Get only item_name and unit_price

# %%
chipo["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
# Crear una nueva columna 'unit_price' con el precio de cada artículo
chipo["unit_price"] = chipo["item_price"]

# Seleccionar solo las columnas 'item_name' y 'unit_price'
result = chipo[["item_name", "unit_price"]]

# Mostrar el resultado
print(result)
# Out:
#                                   item_name  unit_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
# Ordenar el DataFrame por el nombre del artículo 'item_name'
chipo_sorted = chipo[["item_name", "unit_price"]].sort_values(by="item_name")

# Mostrar el DataFrame ordenado
print(chipo_sorted)
# Out:
#               item_name  unit_price
# 3389  6 Pack Soft Drink       12.98
# 341   6 Pack Soft Drink        6.49
# 1849  6 Pack Soft Drink        6.49
# 1860  6 Pack Soft Drink        6.49
# 2713  6 Pack Soft Drink        6.49
# ...                 ...         ...
# 2384  Veggie Soft Tacos        8.75
# 781   Veggie Soft Tacos        8.75
# 2851  Veggie Soft Tacos        8.49
# 1699  Veggie Soft Tacos       11.25
# 1395  Veggie Soft Tacos        8.49
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
chipo["unit_price"].max()
# Out:
# np.float64(11.89)

# %%
max = chipo["unit_price"].max()

# %%
cmax_unit_prices = chipo[chipo["unit_price"]== max]
cmax_unit_prices ["quantity", "unit_price"]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price, unit_price]
# Index: []

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo["item_name"]=="Veggie Salad"]
# Out:
#       order_id  quantity     item_name  \
# 1694       686         1  Veggie Salad
# 2756      1094         1  Veggie Salad
# 2996      1192         1  Veggie Salad
# 3163      1263         1  Veggie Salad
# 3471      1395         1  Veggie Salad
# 4084      1635         1  Veggie Salad
#
#                                      choice_description  item_price  \
# 1694  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...        8.49
# 2756  [[Tomatillo-Green Chili Salsa (Medium), Roaste...        8.49
# 2996  [Roasted Chili Corn Salsa (Medium), [Black Bea...        8.49
# 3163  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...        8.49
# 3471  [[Tomatillo-Green Chili Salsa (Medium), Roaste...        8.49
# 4084  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...        8.49
#
#       unit_price
# 1694        8.49
# 2756        8.49
# 2996        8.49
# 3163        8.49
# 3471        8.49
# 4084        8.49

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?
